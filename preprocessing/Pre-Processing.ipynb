# %%
# from google.colab import drive
# drive.flush_and_unmount()
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

# Đường dẫn file zip
zip_file_path = '/content/drive/MyDrive/real.zip'

# Thư mục để giải nén
extract_folder = '/content/drive/MyDrive/Data'
if not os.path.exists(extract_folder):
    os.makedirs(extract_folder)

# Giải nén file zip
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder)

print(f'Files have been extracted to {extract_folder}')
# Out:
# Files have been extracted to /content/drive/MyDrive/Data

# %%
# !pip3 install face_recognition
# !mkdir '/content/drive/MyDrive/Colab Notebooks/a.kltn/Dataset/Data'
# !pip uninstall -y dlib
# !pip install dlib==19.22.1
# !pip install face_recognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566170 sha256=5cf8228ef51137a2028fa70bcf427648a9457a18ee3642d54c9e12ecfd62a123
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %%
import pandas as pd
import os
import shutil
import json
import glob
import numpy as np
import cv2
import copy
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
from tqdm.autonotebook import tqdm

# %%
path_json = "/content/drive/MyDrive/Datasset/dfdc_train_part_24/metadata.json"
path_csv = "/content/drive/MyDrive/Datasset/dfdc_train_part_24/metadata.csv"
print(path_csv)
print(path_json)
read_json = pd.read_json(path_json)
df = pd.DataFrame(read_json)
df_2 = pd.DataFrame(df.transpose())
df_2.to_csv(path_csv)
read_csv = pd.read_csv(path_csv)
read_csv.columns = ["URI","label","original","split"]
read_csv.to_csv(path_csv,index=False)
print(read_csv.head(5))
# Out:
# /content/drive/MyDrive/Datasset/dfdc_train_part_24/metadata.csv
# /content/drive/MyDrive/Datasset/dfdc_train_part_24/metadata.json
#               URI label original           split
# 0  anijjqtfth.mp4  FAKE    train  qbwwpvgyhh.mp4
# 1  zffofixoeh.mp4  FAKE    train  bjdtgkmvza.mp4
# 2  rkbynalsjc.mp4  FAKE    train  qbwwpvgyhh.mp4
# 3  kyknzgpgvh.mp4  FAKE    train  hyhczxthrs.mp4
# 4  lklxnnznwk.mp4  FAKE    train  sxjdqerkfp.mp4

# %%
# source_folder = '/content/drive/MyDrive/Datasset/Data/Data'
# destination_folder = '/content/drive/MyDrive/Colab Notebooks/a.kltn/Dataset/train'

# # Kiểm tra nếu thư mục đích chưa tồn tại thì tạo mới
# if not os.path.exists(destination_folder):
#     os.makedirs(destination_folder)

# # Di chuyển các tệp .mp4
# for file_name in os.listdir(source_folder):
#     if file_name.endswith('.mp4'):
#         source_file = os.path.join(source_folder, file_name)
#         destination_file = os.path.join(destination_folder, file_name)
#         shutil.move(source_file, destination_file)
#         # print(f'Moved: {file_name}')

# %%
import os

folder_path = '/content/drive/MyDrive/Data/REAL'
file_extension = '.mp4'

file_count = len([f for f in os.listdir(folder_path) if f.endswith(file_extension)])

print(f'Có {file_count} files  "{file_extension}" .')
# Out:
# Có 853 files  ".mp4" .

# %%
import os
import zipfile

# Đường dẫn thư mục cần nén
folder_to_zip = '/content/drive/MyDrive/Data/REAL'

# Đường dẫn tệp ZIP sẽ được tạo
zip_filename = '/content/drive/MyDrive/Data/REAL_DONE.zip'

# Tạo tệp ZIP
with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for root, dirs, files in os.walk(folder_to_zip):
        for file in files:
            zipf.write(os.path.join(root, file),
                       os.path.relpath(os.path.join(root, file),
                       os.path.join(folder_to_zip, '..')))

print(f'Created zip file: {zip_filename}')
# Out:
# Created zip file: /content/drive/MyDrive/Data/REAL_DONE.zip

# %%
from google.colab import files

# Tải tệp ZIP về máy tính
files.download(zip_filename)

# %%
#To get the average frame count
video_files =  glob.glob('/content/drive/MyDrive/Data/real/*.mp4')
frame_count = []
for video_file in video_files:
  cap = cv2.VideoCapture(video_file)
  if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<150):
    video_files.remove(video_file)
    continue
  frame_count.append(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print("frames" , frame_count)
print("Total number of videos: " , len(frame_count))
print('Average frame per video:',np.mean(frame_count))
# Out:
# frames [300, 300, 300, 300, 300, 299, 300, 300, 300, 300, 300, 300, 300, 300, 300, 302, 300, 300, 302, 300, 240, 300, 300, 301, 300, 300, 240, 300, 300, 300, 300, 300, 300, 300, 300, 299, 300, 288, 300, 300, 300, 300, 300, 300, 300, 300, 302, 300, 300, 300, 300, 249, 300, 288, 249, 302, 300, 301, 301, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 299, 300, 300, 300, 300, 300, 249, 300, 300, 300, 299, 240, 300, 300, 300, 300, 299, 300, 302, 300, 300, 300, 300, 300, 302, 300, 300, 300, 302, 300, 302, 300, 249, 302, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 249, 300, 300, 240, 240, 300, 249, 302, 249, 300, 249, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 300, 302, 300, 302, 300, 300, 300, 302, 300, 300, 302, 300, 302, 300, 302, 300, 300, 300, 300, 300, 300, 300, 300, 302, 302, 300, 300, 300, 249, 300, 300, 300, 300, 302, 300, 240, 300, 300, 300, 300, 302, 300, 300, 302, 300, 302, 300, 300, 300, 240, 299, 302, 300, 300, 302, 300, 300, 302, 
# ...

# %%
# extract frame
def frame_extract(path):
  vidObj = cv2.VideoCapture(path)
  success = 1
  while success:
      success, image = vidObj.read()
      if success:
          yield image


# process the frames
def create_face_videos(path_list,out_dir):
  already_present_count =  glob.glob(out_dir+'*.mp4')
  print("No of videos already present " , len(already_present_count))
  for path in tqdm(path_list):
    out_path = os.path.join(out_dir,path.split('/')[-1])
    file_exists = glob.glob(out_path)
    if(len(file_exists) != 0):
      print("File Already exists: " , out_path)
      continue
    frames = []
    flag = 0
    face_all = []
    frames1 = []
    out = cv2.VideoWriter(out_path,cv2.VideoWriter_fourcc('M','J','P','G'), 30, (112,112))
    for idx,frame in enumerate(frame_extract(path)):
      if(idx <= 100):
        frames.append(frame)
        if(len(frames) == 4):
          faces = face_recognition.batch_face_locations(frames)
          for i,face in enumerate(faces):
            if(len(face) != 0):
              top,right,bottom,left = face[0]
            try:
              out.write(cv2.resize(frames[i][top:bottom,left:right,:],(112,112)))
            except:
              pass
          frames = []
    try:
      del top,right,bottom,left
    except:
      pass
    out.release()

# %%
video_files =  glob.glob('/content/drive/MyDrive/Data/real/*.mp4')
create_face_videos(video_files,'/content/drive/MyDrive/Data/REAL')
# Out:
# No of videos already present  0
#   0%|          | 0/853 [00:00<?, ?it/s]
# File Already exists:  /content/drive/MyDrive/Data/REAL/acguxjvmju.mp4
# File Already exists:  /content/drive/MyDrive/Data/REAL/achylfkuww.mp4
# File Already exists:  /content/drive/MyDrive/Data/REAL/acottxtsbq.mp4
# File Already exists:  /content/drive/MyDrive/Data/REAL/acxwjqncgh.mp4
# File Already exists:  /content/drive/MyDrive/Data/REAL/adchpydhaz.mp4
# File Already exists:  /content/drive/MyDrive/Data/REAL/aecilvlrmt.mp4
# File Already exists:  /content/drive/MyDrive/Data/REAL/aeinolstjf.mp4
# File Already exists:  /content/drive/MyDrive/Data/REAL/afbwxsnsjv.mp4
# File Already exists:  /content/drive/MyDrive/Data/REAL/afgplxczaq.mp4
# File Already exists:  /content/drive/MyDrive/Data/REAL/afwzhwbutk.mp4
# File Already exists:  /content/drive/MyDrive/Data/REAL/aivucpvfus.mp4
# File Already exists:  /content/drive/MyDrive/Data/REAL/antppuznjo.mp4
# ...

# %%
import pandas as pd
def number_of_real_and_fake_videos(data_list):
  header_list = ["file","label"]
  lab = pd.read_csv('/content/metadata_24.csv',names=header_list)
  fake = 0
  real = 0
  for i in data_list:
    temp_video = i.split('/')[-1]
    label = lab.iloc[(labels.loc[labels["file"] == temp_video].index.values[0]),1]
    if(label == 'FAKE'):
      fake+=1
    if(label == 'REAL'):
      real+=1
  return real,fake

# %%
import pandas as pd
# header_list = ["file","label"]
labels = pd.read_csv('/content/metadata_35.csv')

print(labels)
# Out:
#                  URI label original           split
# 0     auphqsoduh.mp4  FAKE    train  eofloyspbg.mp4
# 1     vzuxewlhry.mp4  FAKE    train  pqkigveluq.mp4
# 2     jsuhwchxdu.mp4  FAKE    train  ebkatwvaqr.mp4
# 3     uislxipqhe.mp4  FAKE    train  oczpgclisg.mp4
# 4     lkiorkwapx.mp4  FAKE    train  mkenkegdkg.mp4
# ...              ...   ...      ...             ...
# 2535  tnijjjncgd.mp4  FAKE    train  acrfgqyqom.mp4
# 2536  gwmnzgwapx.mp4  REAL    train             NaN
# 2537  drfjrlqbhj.mp4  REAL    train             NaN
# 2538  kwjqhbnooe.mp4  FAKE    train  gwmnzgwapx.mp4
# 2539  irdvfgizvd.mp4  FAKE    train  nrujcvxszu.mp4
#
# [2540 rows x 4 columns]

# %%
# Count the number of occurrences of the label "FAKE"
fake_count = labels[labels['label'] == 'FAKE'].shape[0]
real_count = labels[labels['label'] == 'REAL'].shape[0]

print(f'Total number of files with label "FAKE": {fake_count}')
print(f'Total number of files with label "REAL": {real_count}')
# Out:
# Total number of files with label "FAKE": 2347
# Total number of files with label "REAL": 439

# %%
import shutil



# Lấy danh sách 100 file có label FAKE
fake_files = labels[labels['label'] == 'FAKE']['URI'].tolist()

# Đường dẫn thư mục nguồn và đích
source_dir = '/content/drive/MyDrive/Datasset/Data/Data'  # Thay đổi thành đường dẫn thư mục nguồn của bạn
dest_dir = '/content/drive/MyDrive/Datasset/Data/FAKE'  # Thay đổi thành đường dẫn thư mục đích của bạn

# Tạo thư mục đích nếu chưa tồn tại
os.makedirs(dest_dir, exist_ok=True)

# Di chuyển các tệp
for file_name in fake_files:
    source_file = os.path.join(source_dir, file_name)
    dest_file = os.path.join(dest_dir, file_name)

    if os.path.exists(source_file):
        shutil.move(source_file, dest_file)
        print(f'Moved: {file_name}')
    else:
        print(f'File not found: {file_name}')
# Out:
# File not found: auphqsoduh.mp4
# File not found: vzuxewlhry.mp4
# File not found: jsuhwchxdu.mp4
# File not found: uislxipqhe.mp4
# File not found: lkiorkwapx.mp4
# File not found: mqkkobfofx.mp4
# File not found: hxwlnodvuq.mp4
# File not found: lmvdlokale.mp4
# File not found: ouofnkhqcf.mp4
# File not found: jlnkflvelk.mp4
# File not found: xrjsujvluo.mp4
# File not found: begyynegyx.mp4
# File not found: pvbarubdrg.mp4
# File not found: crfolhbuzh.mp4
# File not found: tiarotbkhs.mp4
# File not found: njiqmszzww.mp4
# File not found: ntcbrfzxop.mp4
# File not found: wurddwxbhk.mp4
# File not found: mdabugzwcq.mp4
# File not found: emfhcuoqdw.mp4
# File not found: csnbiwlwuz.mp4
# File not found: jhroxjxobw.mp4
# File not found: dhbcxyzgez.mp4
# File not found: uqsvynmjuk.mp4
# File not found: ropvntilku.mp4
# File not found: xsufntvtoi.mp4
# File not found: zgrbgpktcp.mp4
# File not found: zpninfabto.mp4
# File not found: bmwzgdjddp.mp4
# File not found: wshoqctusn.mp4
# ...
